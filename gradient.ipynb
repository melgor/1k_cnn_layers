# %%
import pandas as pd

# %%
data = pd.read_csv("skip_wandb_export_2024-12-03T10_56_10.008+01_00.csv")
print(data.shape)
# Out:
# (7898, 25)

# %%
data.head()
# Out:
#    trainer/global_step  \
# 0                    9
# 1                   19
# 2                   29
# 3                   39
# 4                   49
#
#    convnext_28_28_250_28_layerscale_ones_constant_2024_12_01_Dec_16_04_1733065486 - _step  \
# 0                                                1.0
# 1                                                3.0
# 2                                                5.0
# 3                                                7.0
# 4                                                9.0
#
#    convnext_28_28_250_28_layerscale_ones_constant_2024_12_01_Dec_16_04_1733065486 - _step__MIN  \
# 0                                                1.0
# 1                                                3.0
# 2                                                5.0
# 3                                                7.0
# 4                                                9.0
#
# ...

# %%
a = [c for c in data.columns if c.endswith("cnn_0")]

# %%
data[a].mean(axis=0)
# Out:
# convnext_28_28_250_28_layerscale_ones_constant_2024_12_01_Dec_16_04_1733065486 - gradient/cnn_0    0.080271
# convnext_28_28_250_28_layerscale_ones_2024_12_01_Dec_09_56_1733043386 - gradient/cnn_0             0.073386
# convnext_28_28_250_28_layerscale1e6_2024_12_01_Dec_09_20_1733041248 - gradient/cnn_0               0.423389
# convnext_28_28_250_28_2024_11_29_Nov_22_32_1732915975 - gradient/cnn_0                             0.086811
# dtype: float64

# %%
data[a].std(axis=0)
# Out:
# convnext_28_28_250_28_layerscale_ones_constant_2024_12_01_Dec_16_04_1733065486 - gradient/cnn_0    0.137200
# convnext_28_28_250_28_layerscale_ones_2024_12_01_Dec_09_56_1733043386 - gradient/cnn_0             0.124828
# convnext_28_28_250_28_layerscale1e6_2024_12_01_Dec_09_20_1733041248 - gradient/cnn_0               0.208817
# convnext_28_28_250_28_2024_11_29_Nov_22_32_1732915975 - gradient/cnn_0                             0.147486
# dtype: float64

# %%
data[a].describe()
# Out:
#        convnext_28_28_250_28_2024_11_29_Nov_22_32_1732915975 - gradient/cnn_0  \
# count                                       7.898000e+03
# mean                                        8.681122e-02
# std                                         1.474860e-01
# min                                         2.104371e-07
# 25%                                         2.330612e-03
# 50%                                         3.085648e-02
# 75%                                         8.959435e-02
# max                                         1.950112e+00
#
#        convnext_14_14_125_14_2024_11_29_Nov_18_19_1732900753 - gradient/cnn_0  \
# count                                       7.898000e+03
# mean                                        8.468149e-02
# std                                         1.378660e-01
# min                                         8.757914e-08
# 25%                                         2.615811e-03
# 50%                                         3.168971e-02
# ...
